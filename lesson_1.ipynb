# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
y = [1,2,3,4]
x = [22,87,0,18]

plt.plot(x,y)
plt.ylabel("memes")
plt.xlabel("chirps")
plt.title("romey graphy")
# Out:
# Text(0.5, 1.0, 'romey graphy')

# %%
height =[1,2,3,4]
x = [25,50,32,30]
plt.bar(x,height)
plt.xlabel("dog")
plt.title("romey graph")
# Out:
# Text(0.5, 1.0, 'romey graph')

# %%
 
Z = [50,100,150,200]
plt.pie(Z,)
plt.xlabel("chicken")
plt.ylabel("cats")
plt.title("chicks")
# Out:
# Text(0.5, 1.0, 'chicks')
